# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = {
    "Area": [800, 1000, 1200, 1500, 1800],
    "Price": [30, 42, 55, 75, 95]
}

df = pd.DataFrame(data)

# %%
df.to_csv("house_data.csv", index=False)

# %%
df.head()
# Out:
#    Area  Price
# 0   800     30
# 1  1000     42
# 2  1200     55
# 3  1500     75
# 4  1800     95

# %%
# %matplotlib inline

plt.scatter(df['Area'], df['Price'],color='Red', marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area vs Price')
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[1900]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([101.20253165])

# %%
reg.coef_
# Out:
# array([0.06531646])

# %%
reg.intercept_
# Out:
# np.float64(-22.898734177215182)

# %%
0.06531646*1900+(-22.898734177215182)
# Out:
# 101.20253982278484

# %% [markdown]
# Excericse for practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
te = {
    "year": [
        1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,
        1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,
        1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,
        2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,
        2010,2011,2012,2013,2014,2015,2016
    ],
    "per_capita_income_usd": [
        3399.299037,3768.297935,4251.175484,4804.463248,5576.514583,
        5998.144346,7062.131392,7100.12617,7247.967035,7602.912681,
        8355.96812,9434.390652,9619.438377,10416.53659,10790.32872,
        11018.95585,11482.89153,12974.80662,15080.28345,16426.72548,
        16838.6732,17266.09769,16412.08309,15875.58673,15755.82027,
        16369.31725,16699.82668,17310.75775,16622.67187,17581.02414,
        18987.38241,18601.39724,19232.17556,22739.42628,25719.14715,
        29198.05569,32738.2629,36144.48122,37446.48609,32755.17682,
        38420.52289,42334.71121,42665.25597,42676.46837,41039.8936,
        35175.18898,34229.19363
    ]
}

# %%
df.to_csv("income.csv", index=False)

# %%
df.head()
# Out:
#    Area  Price
# 0   800     30
# 1  1000     42
# 2  1200     55
# 3  1500     75
# 4  1800     95

# %%
df.columns
# Out:
# Index(['Area', 'Price'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # removes leading/trailing spaces

# %%
ds.columns = ds.columns.str.strip()                       # remove spaces
ds.columns = ds.columns.str.replace(' ', '_')             # replace spaces with _
ds.columns = ds.columns.str.replace('(', '').str.replace(')', '').str.replace('$','')  # remove brackets and $

# %%
from sklearn.linear_model import LinearRegression

train = LinearRegression()
train.fit(ds[['year']], ds['per_capita_income_US'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'per_capita_income_US'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2774502532.py in <cell line: 0>()
#       2
#       3 train = LinearRegression()
# ----> 4 train.fit(ds[['year']], ds['per_capita_income_US'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'per_capita_income_US'
